# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#from sklearn.cross_validation import train_test_split/

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df = pd.read_csv("diamonds.csv")

# %%
print("DataFrame Head: ")
df.head()
# Out:
# DataFrame Head:
#    index  carat      cut color clarity  depth  table  price     x     y     z
# 0      1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1      2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4      5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
# index      53940 non-null int64
# carat      53940 non-null float64
# cut        53940 non-null object
# color      53940 non-null object
# clarity    53940 non-null object
# depth      53940 non-null float64
# table      53940 non-null float64
# price      53940 non-null int64
# x          53940 non-null float64
# y          53940 non-null float64
# z          53940 non-null float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#               index         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['index', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price',
#        'x', 'y', 'z'],
#       dtype='object')

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(df.isnull (),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.jointplot(x='price',y='carat',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.distplot(df['price'],kde=False,bins=30,color='red')

# %%
sns.distplot(df['depth'],kde=False,bins=30,color='red')

# %%
sns.distplot(df['table'],kde=False,bins=30,color='red')

# %%
sns.rugplot(df['price'])

# %%
sns.lmplot(x="price",y="carat",data=df)

# %%
sns.countplot(x='cut',data=df)

# %%
sns.countplot(x='clarity',data=df)

# %%
cut=sns.barplot(x = 'cut', y = 'price', order=['Fair','Good','Very Good','Premium','Ideal'], data=df)
cut

# %%
color=sns.barplot(x = 'color', y = 'price', order=['J','I','H','G','F','E','D'], data=df)
color

# %%
cla=sns.barplot(x = 'clarity', y = 'price', order=['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF'], data=df)
cla

# %%
g = sns.FacetGrid(data=df,col='clarity')
g.map(plt.hist,'price')

# %%
g = sns.FacetGrid(data=df,col='cut')
g.map(plt.hist,'price')

# %%
g = sns.FacetGrid(data=df,col='color')
g.map(plt.hist,'price')
